# %% [markdown]
# <a href="https://colab.research.google.com/github/MashPotato888/Machine-Learning-Project/blob/main/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("telekinesisai/bin-picking-ball-bearing-02-semi-structured")

print("Path to dataset files:", path)
